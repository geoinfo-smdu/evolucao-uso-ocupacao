# %% [markdown]
# # Análises preliminares

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_eetu = pd.read_csv('resultados/IPTU-uso-do-solo-agg-Eixo.csv')

# %%
df_eetu
# Out:
#     Unnamed: 0     agregacao  area_construida  area_terreno  area_ocupada  \
# 0            0          EETU       73824920.0  4.749051e+07  2.242954e+07
# 1            1  Fora de Eixo      455218382.0  5.682403e+08  2.042439e+08
# 2            0          EETU       61349042.0  4.672124e+07  2.083122e+07
# 3            1  Fora de Eixo      356500352.0  5.427775e+08  1.824679e+08
# 4            0          EETU       53908169.0  4.593393e+07  1.945160e+07
# 5            1  Fora de Eixo      312113566.0  5.376719e+08  1.709292e+08
# 6            0          EETU       65250514.0  4.432761e+07  2.048114e+07
# 7            1  Fora de Eixo      376210300.0  5.203018e+08  1.821635e+08
# 8            0          EETU       60771782.0  4.690932e+07  2.085581e+07
# 9            1  Fora de Eixo      350261098.0  5.426146e+08  1.817624e+08
# 10           0          EETU       72286045.0  4.749757e+07  2.232507e+07
# 11           1  Fora de Eixo      439319814.0  5.610462e+08  2.006428e+08
# ...

# %%
df_eetu_eixo = df_eetu.loc[df_eetu.agregacao == 'EETU']
df_eetu_fora_eixo = df_eetu.loc[df_eetu.agregacao != 'EETU']

# %%
# df_eetu_eixo.sort_values('exercicio').plot.bar(stacked=True, rot=0)
# fig, ax = plt.subplots(1, 1)
df_eetu_eixo.set_index('exercicio').plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='exercicio'>

# %%
df_eetu_fora_eixo.set_index('exercicio').plot.bar(stacked=True, rot=0)
# Out:
# <AxesSubplot:xlabel='exercicio'>

# %%
df_eetu_eixo.set_index('exercicio')[['CA', 'TO']].plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='exercicio'>

# %%
df_eetu_fora_eixo.set_index('exercicio')[['CA', 'TO']].plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='exercicio'>

# %%
df_eetu_fora_eixo.set_index('exercicio')['maximo_de_pavimentos'].plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='exercicio'>
